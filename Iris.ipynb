# %% [markdown]
# <a href="https://colab.research.google.com/github/gmvenge/Assessments/blob/master/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Machine Learning with Iris_Data
# BY Goodwill Mumvenge

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
path="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
iris=pd.read_csv(path,header=None,names=['sepal_length','sepal_width','petal_length','petal_width','Species'])

# %%
#Let's have a look at the dataset
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# So we have Species of Iris Flower and their Sepal Length, Sepal Width, Petal Length, Petal Width is given as the features.

# %%
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # Q : How many data point and features?

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
#(Q) How many data points for each class are present?
print(iris['Species'].value_counts())
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# 2-D Scatter Plot

# %%
# Scatter plot with sepal features as the axis.
iris.plot(kind = 'scatter', x= 'sepal_length', y= 'sepal_width')
plt.show()

# %% [markdown]
# The plot does not makes much sense. Let's try plotting it using seaborn.

# %%
sns.set_style('dark');
sns.FacetGrid(iris, hue= 'Species', height= 5)\
   .map(plt.scatter, 'sepal_length', 'sepal_width')\
   .add_legend();
plt.show()

# %% [markdown]
# On the basis of Sepal Length and Width, we can easily separate "Setosa" from "Versicolor" and "Virginica".
# The red and green points are more intermixed. Let's try and see if we can find some way to separate them using other plots.

# %% [markdown]
# Pair Plots

# %%
#As the number of features is very less, we can easily use pair plots to get some extra insights.

# %%
plt.close();
sns.set_style("dark");
sns.pairplot(iris, hue= 'Species', height= 3);
plt.show()

# %% [markdown]
# Observation(s):
#
# 1.Using sepal_length and sepal_width features, we can distinguish Setosa flowers from others.
#
# 2.Seperating Versicolor from Viginica is much harder as they have considerable overlap.

# %%
# What about 1-D scatter plot using just one feature?
#1-D scatter plot of petal-length
iris_setosa = iris.loc[iris["Species"] == "Iris-setosa"];
iris_virginica = iris.loc[iris["Species"] == "Iris-virginica"];
iris_versicolor = iris.loc[iris["Species"] == "Iris-versicolor"];
#print(iris_setosa["petal_length"])
plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa['petal_length']), 'o')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor['petal_length']), 'o')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica['petal_length']), 'o')

plt.show()

# %%
sns.FacetGrid(iris, hue= 'Species', height= 6)\
   .map(sns.distplot, "petal_length")\
   .add_legend()
plt.show()

# %%
sns.FacetGrid(iris, hue= 'Species', height= 6)\
   .map(sns.distplot, "sepal_length")\
   .add_legend()
plt.show()

# %%
sns.FacetGrid(iris, hue= 'Species', height= 6)\
   .map(sns.distplot, "sepal_width")\
   .add_legend()
plt.show()

# %% [markdown]
# Mean, median and Standard deviation

# %%
print("Mean for setosa's petal length is {}".format(np.mean(iris_setosa['petal_length'])))
print("Mean for versicolor's petal length is {}".format(np.mean(iris_versicolor['petal_length'])))
print("Mean for virginica's petal length is {}".format(np.mean(iris_virginica['petal_length'])))
# Out:
# Mean for setosa's petal length is 1.464
# Mean for versicolor's petal length is 4.26
# Mean for virginica's petal length is 5.552

# %%
print("Std-dev for setosa's petal length is {}".format(np.std(iris_setosa['petal_length'])))
print("Std-dev for versicolor's petal length is {}".format(np.std(iris_versicolor['petal_length'])))
print("Std-dev for virginica's petal length is {}".format(np.std(iris_virginica['petal_length'])))
# Out:
# Std-dev for setosa's petal length is 0.17176728442867115
# Std-dev for versicolor's petal length is 0.4651881339845204
# Std-dev for virginica's petal length is 0.5463478745268441

# %%
print("Median for setosa's petal length is {}".format(np.median(iris_setosa['petal_length'])))
print("Median for versicolor's petal length is {}".format(np.median(iris_versicolor['petal_length'])))
print("Median for virginica's petal length is {}".format(np.median(iris_virginica['petal_length'])))
# Out:
# Median for setosa's petal length is 1.5
# Median for versicolor's petal length is 4.35
# Median for virginica's petal length is 5.55

# %% [markdown]
# Box plot

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x= 'Species', y= 'petal_length', data= iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x= 'Species', y= 'petal_width', data= iris)
plt.show()

# %% [markdown]
# A violin plot combines the benefits of the previous two plots and simplifies them
#
#  Denser regions of the data are fatter, and sparser ones thinner in a violin plot

# %% [markdown]
# Violin plot

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x= 'Species', y= 'sepal_length', data= iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x= 'Species', y= 'sepal_width', data= iris)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x= 'Species', y= 'petal_length', data= iris)
plt.show()

# %%
#2D Density plot, contors-plot
plt.figure(figsize=(10,15))
sns.jointplot(x="petal_length", y="petal_width", data=iris_setosa, kind="kde");
plt.show()

# %% [markdown]
# Darker regions correspond to more density. Points on the same contour have same heights.

# %% [markdown]
# **ML Model**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
X= iris.iloc[:, 0:4]
y= iris.iloc[:, 4]

# %%
X_train,X_test,y_train,y_test= train_test_split(X, y, test_size= 0.15, random_state= 1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_lr = LogisticRegression(solver = 'lbfgs' , multi_class = 'ovr')
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='ovr', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_lr = model_lr.predict(X_test)

# %%
print(confusion_matrix(y_test, pred_lr))
print("Accuracy Using Logistic Regression is {}".format(accuracy_score(y_test, pred_lr)))
# Out:
# [[8 0 0]
#  [0 8 3]
#  [0 0 4]]
# Accuracy Using Logistic Regression is 0.8695652173913043

# %%
from sklearn.svm import SVC

# %%
model_s = SVC( gamma = 'auto')
model_s.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred_s = model_s.predict(X_test)

# %%
print(confusion_matrix(y_test, pred_s))
print("Accuracy Using SVM is {}".format(accuracy_score(y_test, pred_s)))
# Out:
# [[ 8  0  0]
#  [ 0 10  1]
#  [ 0  0  4]]
# Accuracy Using SVM is 0.9565217391304348

# %%
# Let's make the model taking only petal length and width into account

# %%
Xp = iris.iloc[:, 2:4]
yp = iris.iloc[:, 4]

# %%
X_train,X_test,y_train,y_test= train_test_split(Xp, yp, test_size= 0.15, random_state= 1)

# %%
model_s2 = SVC(gamma = 'auto')
model_s2.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred_s2 = model_s2.predict(X_test)

# %%
print(confusion_matrix(y_test, pred_s2))
print("Accuracy Using SVM is {}".format(accuracy_score(y_test, pred_s2)))
# Out:
# [[ 8  0  0]
#  [ 0 10  1]
#  [ 0  0  4]]
# Accuracy Using SVM is 0.9565217391304348

# %% [markdown]
# Neural Network Approach using Pytorch

# %%
len(y)
# Out:
# 150

# %%
import torch
from torch import nn
import torch.nn.functional as F

# %%
# Giving Numerical values to our class labels as we will have to convert them to pytorch tensors.
pd.options.mode.chained_assignment = None
for i in range(len(y)):
    if y[i] == 'Iris-setosa':
        y[i] = 0
    elif y[i] == 'Iris-versicolor':
        y[i] = 1
    else:
        y[i] = 2
  #pd.options.mode.chained_assignment = 'raise'

# %%
y.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: Species, dtype: int64

# %%
from sklearn.preprocessing import normalize
X = normalize(X)

# %%
y = np.array(y)
y = y.astype(int)

# %%
X_train,X_test,y_train,y_test= train_test_split(X, y, test_size= 0.10, random_state= 1)

# %%
from torch import optim

# %%
model = nn.Sequential(nn.Linear(4, 27),
                      nn.ReLU(),
                      nn.Linear(27,9),
                      nn.ReLU(),
                      nn.Linear(9,3),
                      nn.LogSoftmax(dim= 1))

criterion = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.003)

# %%
def train(model, criterion, optimizer, inputs, labels):
    #inputs = Variable(inputs, requires_grad= False)
    #labels = Variable(labels, requires_grad= False)
    
    optimizer.zero_grad()
    output = model(inputs)
    loss = criterion(output, labels)
    
    loss.backward()
    optimizer.step()
    
    return loss.item()

# %%
def predict(model, inputs):
    output = model(inputs)
    return output.data.numpy().argmax(axis= 1)

# %%
X_train = torch.from_numpy(X_train).float()
X_test = torch.from_numpy(X_test).float()
y_train = torch.from_numpy(y_train).long()

# %%
epochs= 100
batch_size= 15
n_batches = 9

# %%
costs = []
test_accuracies = []
for e in range(epochs):
    running_loss = 0
    for j in range(n_batches):
        Xbatch = X_train[j*batch_size:(j+1)*batch_size]
        Ybatch = y_train[j*batch_size:(j+1)*batch_size]
        
        running_loss += train(model, criterion, optimizer, Xbatch, Ybatch)
        
    Ypred = predict(model, X_test)
    acc = np.mean(y_test == Ypred)
    
    print("Epoch: %d, cost: %f, accuracy: %.2f" % (e, running_loss/n_batches, acc))
    
    costs.append(running_loss/n_batches)
    test_accuracies.append(acc)
# Out:
# Epoch: 0, cost: 1.121797, accuracy: 0.40
# Epoch: 1, cost: 1.120670, accuracy: 0.40
# Epoch: 2, cost: 1.119589, accuracy: 0.40
# Epoch: 3, cost: 1.118550, accuracy: 0.40
# Epoch: 4, cost: 1.117551, accuracy: 0.40
# Epoch: 5, cost: 1.116592, accuracy: 0.40
# Epoch: 6, cost: 1.115669, accuracy: 0.40
# Epoch: 7, cost: 1.114781, accuracy: 0.40
# Epoch: 8, cost: 1.113927, accuracy: 0.40
# Epoch: 9, cost: 1.113105, accuracy: 0.40
# Epoch: 10, cost: 1.112313, accuracy: 0.40
# Epoch: 11, cost: 1.111550, accuracy: 0.40
# Epoch: 12, cost: 1.110815, accuracy: 0.40
# Epoch: 13, cost: 1.110107, accuracy: 0.40
# Epoch: 14, cost: 1.109425, accuracy: 0.40
# Epoch: 15, cost: 1.108767, accuracy: 0.40
# Epoch: 16, cost: 1.108132, accuracy: 0.40
# Epoch: 17, cost: 1.107520, accuracy: 0.40
# Epoch: 18, cost: 1.106929, accuracy: 0.40
# Epoch: 19, cost: 1.106366, accuracy: 0.40
# Epoch: 20, cost: 1.105842, accuracy: 0.40
# Epoch: 21, cost: 1.105278, accuracy: 0.40
# ...

# %%
# %matplotlib inline

# %%
plt.plot(costs)
plt.title("Training Costs")
plt.show()

# %%
plt.plot(test_accuracies)
plt.title("Test Accuracies")
plt.show()

# %%
ypred = predict(model, X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
print(confusion_matrix(y_test, ypred))
print("Accuracy Score is {}".format(accuracy_score(y_test, ypred)))
# Out:
# [[4 1 0]
#  [0 6 0]
#  [0 4 0]]
# Accuracy Score is 0.6666666666666666
